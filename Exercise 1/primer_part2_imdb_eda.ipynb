# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# [Tip]: To execute the Python code in the code cell below, click on the cell to select it and press <kbd>Shift</kbd> + <kbd>Enter</kbd>.
# </div>
# <hr/>
#
# # Exercise 1: IMDB Part 2
#
# ## This exercise is split into two notebooks
#
# 1. Part: Scraping IMDB (the other notebook)
# 2. Part: Exploratory Data Analysis (this notebook)
#
#
# ## Part 2: Exploratory Data Analysis
#
# You have to correctly implement (at least) **five** of the following 10 queries:
#
# * Patience
# * Binge Watching Steven Spielberg
# * This is about me
# * Workhorse
# * Cashhorse
# * Beloved Genres
# * Must See
# * Uncreative writers
# * Glamour of hollywood
# * Chat Client
#
# ### You have to hand in this exercise via Moodle.
#
# <img src="images/imdb.png">

# %% [markdown]
# # Importing Pre-Requisites
#
# First we need to install the required libraries

# %%
# %config InlineBackend.figure_formats = {'png', 'retina'}

import numpy as np
import pandas as pd

from os.path import exists

# %% [markdown]
# We first load the crawled IMDB-data in JSON Format to a Pandas Dataframe.

# %%
def load_movies_json():
    
    local = "data/movies_full_crawled.json"
    if exists(local):
        print ("Read from local file")
        return pd.read_json(local)
    else:
        print ("Read from hu-box")        
        return pd.read_json("https://box.hu-berlin.de/f/bd7bdd460c55420783aa/?dl=1")

movies = load_movies_json()
movies.head(2)
# Out:
# Read from local file
#                  url                     title  ratingValue  ratingCount  \
# 0  /title/tt0111161/  The Shawshank Redemption          9.3      3100000
# 1  /title/tt0068646/             The Godfather          9.2      2200000
#
#    year                                        description  \
# 0  1994  A banker convicted of uxoricide forms a friend...
# 1  1972  The aging patriarch of an organized crime dyna...
#
#                     budget      gross  duration  \
# 0  $25,000,000 (estimated)   29334033       142
# 1   $6,000,000 (estimated)  250924773       175
#
#                                    genreList      countryList  \
# 0  [Epic, Period Drama, Prison Drama, Drama]  [United States]
# 1    [Epic, Gangster, Tragedy, Crime, Drama]  [United States]
#
#                                             castList  \
# 0  [Tim Robbins, Morgan Freeman, Bob Gunton, Will...
# 1  [Marlon Brando, Al Pacino, James Caan, Richard...
#
#                                        characterList            directorList
# 0  [Andy Dufresne, Ellis Boyd 'Red' Redding, Ward...        [Frank Darabont]
# 1  [Don Vito Corleone, Michael, Sonny, Clemenza, ...  [Francis Ford Coppola]

# %%
movies = movies.convert_dtypes()
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 0 to 249
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            250 non-null    string
#  1   title          250 non-null    string
#  2   ratingValue    250 non-null    Float64
#  3   ratingCount    250 non-null    Int64
#  4   year           250 non-null    Int64
#  5   description    250 non-null    string
#  6   budget         250 non-null    object
#  7   gross          250 non-null    Int64
#  8   duration       250 non-null    Int64
#  9   genreList      250 non-null    object
#  10  countryList    250 non-null    object
#  11  castList       250 non-null    object
#  12  characterList  250 non-null    object
#  13  directorList   250 non-null    object
# dtypes: Float64(1), Int64(4), object(6), string(3)
# memory usage: 30.5+ KB

# %% [markdown]
# <hr/>
#
# ## Examples
#
# Next, we will see some exemplary queries on this data, including
#
# - Boolean Filtering
# - Ranking
# - Grouping
# - Aggregation
# - Counting
# - Sorting

# %% [markdown]
# ### Get the first 2 entries from the dataframe

# %%
result = movies.iloc[:2]
result[["title", "url"]]
# Out:
#                       title                url
# 0  The Shawshank Redemption  /title/tt0111161/
# 1             The Godfather  /title/tt0068646/

# %% [markdown]
# ### TOP-5 movies by largest gross

# %%
result = movies.sort_values(by="gross", ascending=False).iloc[:5]
result[["title", "gross"]]
# Out:
#                                             title       gross
# 77                              Avengers: Endgame  2799439100
# 62                         Avengers: Infinity War  2052415039
# 142                       Spider-Man: No Way Home  1921426073
# 81                              Top Gun: Maverick  1495696292
# 180  Harry Potter and the Deathly Hallows: Part 2  1342505340

# %% [markdown]
# ### Get the Total Number of Movies with a rating above or equal to 9

# %%
# we first create a boolean filter on the data
movies["ratingValue"] >= 9.0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# Name: ratingValue, Length: 250, dtype: boolean

# %%
# apply it to the data
movies[movies["ratingValue"] >= 9.0][["title", "ratingCount"]]
# Out:
#                                            title  ratingCount
# 0                       The Shawshank Redemption      3100000
# 1                                  The Godfather      2200000
# 2                                The Dark Knight      3100000
# 3                          The Godfather Part II      1500000
# 4                                   12 Angry Men       953000
# 5                               Schindler's List      1600000
# 6  The Lord of the Rings: The Return of the King      2100000

# %%
# Using shape
result = movies[ movies["ratingValue"] >= 9.0 ].shape[0]
print(result)
# Out:
# 7

# %% [markdown]
# ### Total Count of Action Movies
#
# We may use `explode` to unroll list-types in cells. This effectively creates a copy for each value in the list.

# %%
# First create duplicates to unroll the genre-list into own rows.
df = movies.explode('genreList')
df[df.title=="The Godfather"][["title", "genreList"]]
# Out:
#            title genreList
# 1  The Godfather      Epic
# 1  The Godfather  Gangster
# 1  The Godfather   Tragedy
# 1  The Godfather     Crime
# 1  The Godfather     Drama

# %%
# First create duplicates to unroll the genre-list into own rows.
df = movies.explode('genreList')
df[df.title=="The Godfather"][["title", "genreList"]]
# Out:
#            title genreList
# 1  The Godfather      Epic
# 1  The Godfather  Gangster
# 1  The Godfather   Tragedy
# 1  The Godfather     Crime
# 1  The Godfather     Drama

# %% [markdown]
# Using the exploded dataframe, we may seach for all action movies

# %%
# The filter by genre 'Action' and apply counting
result = df[ df["genreList"]=="Action" ].shape[0]
result
# Out:
# 41

# %%
# Filter by substr 'action' and apply counting
result = df[ df["genreList"].str.lower().str.contains("action") ].shape[0]
result
# Out:
# 77

# %% [markdown]
# ### Sum of Gross by all Countries of Origin
#
# Applying grouping and sorting to the data

# %%
# First create duplicates to unroll the country-list into own rows.
df = movies.explode('countryList')
df[["title", "countryList","gross"]]
# Out:
#                         title     countryList       gross
# 0    The Shawshank Redemption   United States    29334033
# 1               The Godfather   United States   250924773
# 2             The Dark Knight   United States  1009242873
# 2             The Dark Knight  United Kingdom  1009242873
# 3       The Godfather Part II   United States    48105107
# ..                        ...             ...         ...
# 248            The Iron Giant   United States    23339506
# 248            The Iron Giant  Czech Republic    23339506
# 248            The Iron Giant  United Kingdom    23339506
# 249                    Gandhi  United Kingdom    52768419
# 249                    Gandhi           India    52768419
#
# [385 rows x 3 columns]

# %%
# Group the data, aggregate and sort the result
result = df.groupby("countryList")[["gross"]]\
        .sum() \
        .sort_values(by="gross", ascending=False)
display(result)

_ = result.plot(kind="bar")
# Out:
#                       gross
# countryList
# United States   52038303611
# United Kingdom  10461166431
# New Zealand      2967726132
# Canada           2922304115
# Australia        2893565333
# Japan            2862006452
# France           2232887468
# Norway           2052415039
# Germany          1492098625
# Mexico            919413204
# Italy             896467749
# Spain             664869815
# India             660592850
# Jordan            474171806
# Morocco           465516248
# Malta             465516248
# Hong Kong         333880267
# China             321752656
# South Korea       319229449
# Poland            120098945
# Ireland           101199628
# Austria            98758931
# Argentina          66558543
# Qatar              64417003
# Lebanon            64417003
# Cyprus             64417003
# West Germany       51764952
# South Africa       33882243
# Brazil             30681033
# Iran               23860009
# Czech Republic     23339506
# Soviet Union       20944128
# Turkey             18612999
# Sweden             16370360
# Denmark            15886373
# Belgium            15886373
# Algeria              962002

# %% [markdown]
# ### Count of Movies by Genre
#
# Count the number of movies in each genre.

# %%
# First create duplicates to unroll the country-list into own rows,
# then count the number of movies in each genre
result = movies.explode('genreList')["genreList"].value_counts()
                   
# Finally, plot the result
_ = result.plot(kind="bar", figsize=(25, 3))

# %% [markdown]
# ### Cheat-Sheet
#
# If you need further inspiration, have a look here:
# <a href="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Pandas Cheat-Sheet</a>
#
# <img src="images/wrangling.png" width="300"/>

# %% [markdown]
# # Now it is your time to implement the following queries
#
# You must correctly solve at least **four** out of **ten** queries.

# %% [markdown]
# ### Query 1: Patience
#
# <div class="alert alert-block alert-success">
# Select all movies with a duration above or equal to 220 minutes.
# </div>

# %%
result = None

# ADD YOUR CODE HERE

result = movies[movies["duration"] >= 220]

# DO NOT CHANGE FROM HERE 
    
result
# Out:
#                    url                        title  ratingValue  ratingCount  \
# 79   /title/tt0087843/  Once Upon a Time in America          8.3       401000
# 97   /title/tt0056172/           Lawrence of Arabia          8.3       335000
# 158  /title/tt0031381/           Gone with the Wind          8.2       351000
#
#      year                                        description  \
# 79   1984  A former Prohibition-era Jewish gangster retur...
# 97   1962  The story of T.E. Lawrence, the English office...
# 158  1939  A sheltered and manipulative Southern belle an...
#
#                       budget      gross  duration  \
# 79   $30,000,000 (estimated)    5476126       229
# 97   $15,000,000 (estimated)   45995357       227
# 158   $3,977,000 (estimated)  402382193       238
#
#                                              genreList  \
# 79   [Dark Comedy, Epic, Gangster, Period Drama, Cr...
# 97   [Adventure Epic, Desert Adventure, Epic, Trage...
# 158  [Costume Drama, Epic, Period Drama, Romantic E...
#
#                          countryList  \
# 79            [Italy, United States]
# 97   [United Kingdom, United States]
# 158                  [United States]
#
#                                               castList  \
# 79   [Robert De Niro, James Woods, Elizabeth McGove...
# 97   [Peter O'Toole, Alec Guinness, Anthony Quinn, ...
# 158  [Thomas Mitchell, Barbara O'Neil, Vivien Leigh...
#
#                                          characterList      directorList
# 79   [Noodles, Max, Deborah, Jimmy O'Donnell, Carol...    [Sergio Leone]
# 97   [Lawrence, Prince Faisal, Auda Abu Tayi, Gener...      [David Lean]
# 158  [Gerald O'Hara, Ellen, his wife, Scarlett, Sue...  [Victor Fleming]

# %% [markdown]
# ### Query 2: Binge Watching Steven Spielberg
#
# <div class="alert alert-block alert-success">
# Select the total duration of all movies directed by Steven Spielberg.
# </div>

# %%
result = None

# ADD YOUR CODE HERE

df = movies.explode("directorList")
result = df[df["directorList"] == "Steven Spielberg"]

# DO NOT CHANGE FROM HERE 

result
# Out:
#                    url                               title  ratingValue  \
# 5    /title/tt0108052/                    Schindler's List          9.0
# 23   /title/tt0120815/                 Saving Private Ryan          8.6
# 54   /title/tt0082971/             Raiders of the Lost Ark          8.4
# 120  /title/tt0097576/  Indiana Jones and the Last Crusade          8.2
# 147  /title/tt0107290/                       Jurassic Park          8.2
# 173  /title/tt0264464/                 Catch Me If You Can          8.1
# 204  /title/tt0073195/                                Jaws          8.1
#
#      ratingCount  year                                        description  \
# 5        1600000  1993  In German-occupied Poland during World War II,...
# 23       1600000  1998  Following the Normandy Landings, a group of U....
# 54       1100000  1981  In 1936, archaeologist Indiana Jones is tasked...
# 120       850000  1989  In 1938, after his father goes missing while p...
# 147      1100000  1993  An industrialist invites some experts to visit...
# 173      1200000  2002  Barely 17 yet, Frank is a skilled forger who h...
# 204       720000  1975  When a massive killer shark unleashes chaos on...
#
#                       budget       gross  duration  \
# 5    $22,000,000 (estimated)   322161245       195
# 23   $70,000,000 (estimated)   482352390       169
# 54   $18,000,000 (estimated)   389925971       115
# 120  $48,000,000 (estimated)   474171806       127
# 147  $63,000,000 (estimated)  1104379926       127
# 173  $52,000,000 (estimated)   352114312       141
# 204   $7,000,000 (estimated)   490736300       124
#
#                                              genreList  \
# 5    [Docudrama, Epic, Historical Epic, Period Dram...
# 23   [Epic, Period Drama, Psychological Drama, Trag...
# 54   [Action Epic, Adventure Epic, Desert Adventure...
# 120  [Action Epic, Adventure Epic, Desert Adventure...
# 147  [Dinosaur Adventure, Jungle Adventure, Action,...
# 173  [Caper, Coming-of-Age, Docudrama, Globetrottin...
# 204  [Disaster, Monster Horror, Sea Adventure, Surv...
#
#                                            countryList  \
# 5                                      [United States]
# 23                                     [United States]
# 54                                     [United States]
# 120  [United States, Italy, Spain, United Kingdom, ...
# 147                                    [United States]
# 173                            [United States, Canada]
# 204                                    [United States]
#
#                                               castList  \
# 5    [Liam Neeson, Ben Kingsley, Ralph Fiennes, Car...
# 23   [Tom Hanks, Tom Sizemore, Edward Burns, Barry ...
# 54   [Harrison Ford, Karen Allen, Paul Freeman, Ron...
# 120  [Harrison Ford, Sean Connery, Denholm Elliott,...
# 147  [Sam Neill, Laura Dern, Jeff Goldblum, Richard...
# 173  [Leonardo DiCaprio, Tom Hanks, Christopher Wal...
# 204  [Roy Scheider, Robert Shaw, Richard Dreyfuss, ...
#
#                                          characterList      directorList
# 5    [Oskar Schindler, Itzhak Stern, Amon Goeth, Em...  Steven Spielberg
# 23   [Captain Miller, Sergeant Horvath, Private Rei...  Steven Spielberg
# 54   [Indy, Marion, Belloq, Toht, Sallah, Brody, Sa...  Steven Spielberg
# 120  [Indiana Jones, Professor Henry Jones, Marcus ...  Steven Spielberg
# 147  [Grant, Ellie, Malcolm, Hammond, Muldoon, Genn...  Steven Spielberg
# 173  [Frank Abagnale Jr., Carl Hanratty, Frank Abag...  Steven Spielberg
# 204  [Brody, Quint, Hooper, Ellen Brody, Vaughn, Me...  Steven Spielberg

# %% [markdown]
# ### Query 3: This is about me
#
# <div class="alert alert-block alert-success">
# Provide a ranked list of the TOP-10 actors with the most screen-time, as counted by total duration of the movies they are starring in.
#
# The result will be plotted.
# </div>

# %%
result = None

# ADD YOUR CODE HERE

df = movies.explode("castList")
result = df.groupby("castList")[["duration"]]\
        .sum() \
        .sort_values(by="duration", ascending=False) \
        .iloc[:10]

# DO NOT CHANGE FROM HERE 

if result is not None:
    result.plot(kind="bar", figsize=(10, 3))

# %% [markdown]
# ### Query 4: Workhorse
#
# <div class="alert alert-block alert-success">
# Provide a ranked list of the TOP-10 most active actors (cast), i.e., those actors which have starred in most movies.
#
# The result will be plotted.
# </div>

# %%
result = None

# ADD YOUR CODE HERE

df = movies.explode("castList")
result = df.groupby("castList")["title"]\
        .count()\
        .sort_values(ascending=False)\
        .iloc[:10]

# DO NOT CHANGE FROM HERE 

if result is not None:
    _ = result.plot(kind="bar", figsize=(10, 3))

# %% [markdown]
# ### Query 5: Cashhorse
#
# <div class="alert alert-block alert-success">
# Provide a ranked list of the TOP-10 most successful actors (cast),
# i.e., those actors which have generated the most gross.
#
# The result will be plotted.
# </div>

# %%
result = None

# ADD YOUR CODE HERE

df = movies.explode("castList")
result = df.groupby("castList")[["gross"]]\
        .sum() \
        .sort_values(by="gross", ascending=False) \
        .iloc[:10]

# DO NOT CHANGE FROM HERE 


if result is not None:
    _ =  result.plot(kind="bar", figsize=(10, 3))

# %% [markdown]
# ### Query 6: Beloved Genres
#
# <div class="alert alert-block alert-success">
# Provide a ranked list of the TOP-10 most successful genres, i.e., those genres which have generated the most gross.
#
# The result will be plotted.
# </div>

# %%
result = None

# ADD YOUR CODE HERE

df = movies.explode("genreList")
result = df.groupby("genreList")[["gross"]]\
        .sum() \
        .sort_values(by="gross", ascending=False) \
        .iloc[:10]

# DO NOT CHANGE FROM HERE 


if result is not None:
    _ = result.plot(kind="bar", figsize=(10, 3))

# %% [markdown]
# ### Query 7: Must See
#
# <div class="alert alert-block alert-success">
# List the best rated movie of each year starting from (including) 1990 until (including) 2000. Order the movies by increasing year. The result must contain exactly 11 rows.
# </div>
#
# **Hint:** `df.head(1)` may be usefull

# %%
result = None

# ADD YOUR CODE HERE

df = movies[movies["year"] >= 1990]
result = df.groupby("year")[["title","ratingValue"]].max().head(11)

# DO NOT CHANGE FROM HERE 



result
# Out:
#                          title  ratingValue
# year
# 1990                Goodfellas          8.7
# 1991  The Silence of the Lambs          8.6
# 1992                Unforgiven          8.3
# 1993          Schindler's List          9.0
# 1994  The Shawshank Redemption          9.3
# 1995                 Toy Story          8.6
# 1996             Trainspotting          8.1
# 1997         Princess Mononoke          8.6
# 1998           The Truman Show          8.6
# 1999           The Sixth Sense          8.8
# 2000                    Snatch          8.5

# %% [markdown]
# ### Query 8: Uncreative writers
#
# <div class="alert alert-block alert-success">
# Provide a ranked list of the TOP-10 most frequent character names of all times ordered by the frequency of occurrence in movies.
#
# The result will be plotted.
# </div>

# %%
result = None 

# ADD YOUR CODE HERE

df = movies.explode("characterList")
result = df.groupby("characterList")["title"]\
        .count()\
        .sort_values(ascending=False)\
        .iloc[:10]

# DO NOT CHANGE FROM HERE 


if result is not None:
    _ = result.plot(kind="bar", figsize=(10, 3))

# %% [markdown]
# ### Query 9: Glamour of hollywood
#
# <div class="alert alert-block alert-success">
# Compute the cumulative gross over the years.
#
# The result will be plotted.
# </div>

# %%
result = None 

# ADD YOUR CODE HERE

result = movies.groupby("year")[["title","gross"]].sum()

# DO NOT CHANGE FROM HERE 


if result is not None:
    _ = result.plot(kind="line", figsize=(10, 3))

# %% [markdown]
# ### Query 10: IMDB Chat Client (Optional Task)
#
# <div class="alert alert-block alert-success">
# Implement a chat bot using MISTRAL, that answers any question to the dataset, you give using only the dataset provided.
# </div>
#
# You must connect to this endpoint:
#
# ```python
# from openai import OpenAI
# base_url = "https://llm3-compute.cms.hu-berlin.de/v1/"
# OPENAI_API_KEY = "secret but not used"
# client = OpenAI(base_url=base_url, api_key=OPENAI_API_KEY)
# ```
#
# For this to work, you must be connected to the HU Intranet (using either **HU VPN** or HU **Intranet**).
#
# Use this page, to check, if you have a HU internal IP:
# <br/>https://amor.cms.hu-berlin.de/account/ip.cgi
#
# Then, create a chat using
#
# ```python
# resp = client.chat.completions.create(...)
# out = resp.choices[0].message.content.strip().lower()
# print(out)
# ```
#
# Pay attention to the **prompt** used.

# %%
### Uncomment, if needed to install the openai library

try:
    from openai import OpenAI
except ImportError as e:
    # !pip install openai

# %% [markdown]
# ### Ask any Questions About Your Data

# %%
from openai import OpenAI
base_url = "https://llm3-compute.cms.hu-berlin.de/v1/"
OPENAI_API_KEY = "secret but not used"
client = OpenAI(base_url=base_url, api_key=OPENAI_API_KEY, timeout=5)

def ask_user_question(user_question, text):   

    # ADD YOUR CODE HERE
    
    print(f"Question: '{user_question}'")
    stream = []

    
    for chunk in stream:
            if chunk.choices[0].delta.content is not None:
                content = chunk.choices[0].delta.content
                print(content, end='', flush=True)  # Print tokens as they arrive

# %%
# DO NO CHANGE THIS CODE
movies_sub = movies.iloc[:, ~movies.columns.isin([
    'genreList','countryList','castList','characterList','directorList'])]
text = movies_sub.to_string()

user_question = "I like SciFi, and Comedies. Can you recommend a movie to me?"
ask_user_question(user_question, text)               
print("\n")

user_question = "How many movies mention american cities?"
ask_user_question(user_question, text)               
print("\n")

user_question = "Which 5 movies do I have to see if I enjoy SciFi?"
ask_user_question(user_question, text)       
print("\n")
# Out:
# Question: 'I like SciFi, and Comedies. Can you recommend a movie to me?'
#
#
# Question: 'How many movies mention american cities?'
#
#
# Question: 'Which 5 movies do I have to see if I enjoy SciFi?'

# %% [markdown]
# <hr/>
#
# # Submit via Moodle:
# - HTML-exports of the notebooks for part 1 and part 2
# - Source-codes of the notebooks for part 1 and part 2
# - The json export `part1_submission.json` of the TOP 250 movies.
